# %%
import numpy as np
import pandas as pd
import seaborn as sns            # Why sns?  It's a reference to The West Wing
import matplotlib.pyplot as plt  # seaborn is based on matplotlib
sns.set(color_codes=True)        # adds a nice background to the graphs
# %matplotlib inline  
# tells python to actually display the graphs

# %%
auto = pd.read_csv('Automobile.csv')
auto.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %% [markdown]
# # Different Graphs
# - Continuous
# - Categorical

# %% [markdown]
# ## Histogram

# %%
sns.distplot(auto['highway_mpg'], kde=False, rug=True);
# Kde: Kernel Density Estimate shows the line
# rug: shows the data points
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(x=auto['highway_mpg'],hue=auto['fuel_type']);
sns.displot(x=auto['highway_mpg'],bins=[0,20,40,50,70],hue=auto['fuel_type']);

# %%
sns.histplot(auto['highway_mpg'],bins=[0,20,40,50,70]);
             #hue=auto['fuel_type']);

# %% [markdown]
# # # Scatter Plot

# %%
sns.jointplot(x= auto['engine_size'], y=auto['horsepower'], kind='hex');
#sns.jointplot(x= auto['engine_size'], y=auto['horsepower'], kind='kde');
#sns.jointplot(x= auto['engine_size'], y=auto['horsepower'], kind='scatter'); # default
# kind : { "scatter" | "kde" | "hist" | "hex" | "reg" | "resid" }

# %%
sns.pairplot(auto[['normalized_losses', 'engine_size','horsepower']]);

# %%
sns.stripplot(x=auto['fuel_type'], y=auto['horsepower'], jitter=True);

# %%
sns.swarmplot(x=auto['fuel_type'], y=auto['horsepower'],size=3);

# %%
sns.boxplot(x=auto['number_of_doors'], y=auto['horsepower']);

# %% [markdown]
# ### Explanation
# displays Q1, Q2, Q3, Q4
#
# box is Q2,Q4
#
# Inter Quartile Range IQR = Q3-Q1
#
# As a rule of thumb anything above Q4 + (IQR*1.5) is considered outlier
#
#                anything below Q1 - (IQR*1.5) is considered outlier

# %%
sns.boxplot(x=auto['number_of_doors'], y=auto['horsepower'], hue=auto['fuel_type']);

# %%
sns.barplot(x=auto['body_style'], y=auto['horsepower'], hue=auto['fuel_type']);

# %%
sns.countplot(x=auto['body_style'],hue=auto['fuel_type']);

# %%
sns.pointplot(x=auto['body_style'], y=auto['horsepower'], hue=auto['number_of_doors'],linestyles='');

# %%
sns.catplot(x="fuel_type",
               y = "horsepower",
               hue="number_of_doors", 
               col="drive_wheels", 
               data=auto, 
               kind="box");

# multipanel layout - (boxplot reference)

# %%
sns.lmplot(y="horsepower", x="engine_size", data=auto);

# %%
sns.lmplot(y="horsepower", x="engine_size",hue="fuel_type", data=auto);

# %% [markdown]
# ## Line Plot

# %%
x = np.arange(0,11)
y = x*2
plt.plot(x,y,color='g', linewidth=2, linestyle=":")
plt.title('Line Plot')
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.show()

# %%
x = np.arange(0,11)
y1 = x*2
y2 = y*3
plt.plot(x,y1,color='g', linewidth=2, linestyle=":")
plt.plot(x,y2,color='r', linewidth=2, linestyle="-.")
plt.title('Line Plot')
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.grid(True)
plt.show()

# %%
x = np.arange(0,11)
y1 = x*2
y2 = y*3
plt.subplot(1,2,1)                                             # row, column, order
plt.plot(x,y1,color='g', linewidth=2, linestyle=":")
plt.subplot(1,2,2)                                             # row, column, order
plt.plot(x,y2,color='r', linewidth=2, linestyle="-.")
plt.title('Line Plot')
plt.xlabel('X Label')
plt.ylabel('Y Label')
#plt.grid(True)


plt.show()

# %% [markdown]
# # ## Scatter Plot

# %%
x = [10,20,30,40,50,60,70,80]
y = np.array(np.random.randint(1,100,8))
y2 = np.array(np.random.randint(1,100,8))

# %%
x, y
# Out:
# ([10, 20, 30, 40, 50, 60, 70, 80], array([78, 40, 13, 67, 65, 62, 90, 78]))

# %%
plt.scatter(x,y,marker='*', c='g', s=100)
plt.show().

# %%
plt.scatter(x,y,marker='*', c='g', s=100)
plt.scatter(x,y2,marker='.', c='r', s=300)
plt.show()

# %%
plt.subplot(1,2,1)
plt.scatter(x,y,marker='*', c='g', s=100)
plt.subplot(1,2,2)
plt.scatter(x,y2,marker='.', c='r', s=300)
plt.show()

# %% [markdown]
# ## Bar Plot

# %%
student = {"Sam":67, "Matt":23, "Julia":98}
x = list(student.keys())
y = list(student.values())
plt.title('Bar Plot')
plt.xlabel('Student')
plt.ylabel('Marks')
plt.bar(x,y,color='g')
plt.grid(True)
plt.show()

# %%
student = {"Sam":67, "Matt":23, "Julia":98}
x = list(student.keys())
y = list(student.values())
plt.title('Bar Plot')
plt.xlabel('Student')
plt.ylabel('Marks')
plt.barh(x,y,color='r')                                  #Horizontal Bar
plt.grid(True)
plt.show()

# %% [markdown]
# ## Histogram

# %%
data = [8,8,9,4,6,7,3,1,2,6,5,4,8]
plt.hist(data)
plt.xticks(rotation=90)                                # x lable rotated by 90%
plt.show()

# %%
iris_df = pd.read_csv('Iris.csv')
iris_df['SepalWidthCm'].nunique()
# Out:
# 23

# %%
plt.hist(iris_df['SepalWidthCm'],bins=23,color='orange')
plt.show()

# %% [markdown]
# ## Box Plot & Violin Plot

# %%
x = np.random.randint(1,10,8)
y = np.random.randint(1,10,8)
z = np.random.randint(1,10,8)

data = [x,y,z]
plt.boxplot(data)
print(x, '\n',y,'\n',z,'\n')
plt.show()
# Out:
# [3 6 1 7 4 5 9 7]
#  [2 9 9 4 8 9 3 1]
#  [4 1 6 3 6 9 5 5]

# %%
x = np.random.randint(1,10,8)
y = np.random.randint(1,10,8)
z = np.random.randint(1,10,8)

data = [x,y,z]
plt.violinplot(data)
print(x, '\n',y,'\n',z,'\n')
plt.show()
# Out:
# [1 3 3 7 5 4 7 4]
#  [5 1 8 6 5 4 5 3]
#  [3 5 1 3 7 9 7 1]

# %% [markdown]
# ## Piechart & Doughnut Chart

# %%
data_dict = {"Apple":34, "Guava":45,"Orange":23}
plt.pie(data_dict.values(), labels=data_dict.keys(), autopct='%0.1f%%', colors=['red','green','yellow'])
plt.show()

# %%
data_dict = {"Apple":34, "Guava":45,"Orange":23}
plt.pie(data_dict.values(), labels=data_dict.keys(), autopct='%0.1f%%', colors=['red','green','yellow'], radius=2)  # outer pie with a bigger radius
plt.pie([1],colors=['white'], radius=1)   ## set 1 item with white clor and radius lesser than outer pie
plt.show()

# %% [markdown]
# # Practice

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_palette("deep") 
#sns.set(color_codes=True)

# %%
data_amz = pd.read_csv('amazon_data.csv')
data_amz.head()
# Out:
#                                         product name        asin  \
# 0  BHAGIRATH Standard comfort Disposable Pollutio...  B085GL266P
# 1  ShopyBucket Standard 3 PCS comfort Disposable ...  B0855V7MQ8
# 2  Gnexin ISI Approved Mask RespiratorPollutionAn...  B084M511KM
# 3  Kodenipr Club Disposable Stretchable Blue Bouf...  B0777HKWJF
# 4                SMARTCARE Face Mask Cloth Tie Green  B079CHH5M3
#
#                                          product url     brand name  \
# 0  https://www.amazon.in/BHAGIRATH-Standard-Dispo...  Bhagirath fab
# 1  https://www.amazon.in/ShopyBucket-Standard-Dis...          Shopy
# 2  https://www.amazon.in/Gnexin-Approved-Respirat...         Gnexin
# 3  https://www.amazon.in/Aurum-Creations-Disposab...  KODENIPR CLUB
# 4  https://www.amazon.in/Smart-Care-Face-Cloth-Gr...      SMARTCARE
#
#                                            image url    mrp  sale price  \
# 0  https://images-na.ssl-images-amazon.com/images...  16999         199
# ...

# %%
sns.pairplot(data_amz);

# %%
sns.distplot(x=data_amz['discount percentage'],hist=False)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(x=data_amz['discount percentage'],hist=False)
plt.xticks(rotation=90) 
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
df= sns.load_dataset("iris")
print(df['species'].value_counts())
sns.countplot(x=df.species);
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
df= sns.load_dataset("iris")
df.boxplot(figsize=(12,7))                          ## ability to create a boxplot directly from dataframe
# Out:
# <AxesSubplot:>
